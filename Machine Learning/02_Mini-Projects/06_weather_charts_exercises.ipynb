# %% [markdown]
# # Exercise: Weather Charts
#
# Tasks:
# 1. Create the fake weather DataFrame (day,temp,humidity).
# 2. Plot temperature as a line with markers.
# 3. Make a scatter plot of humidity vs temp.
# 4. Make a histogram of temp.
# 5. Save the line plot to `/mnt/data/ml_projects/weather_line_exercise.png`.

# %%
# YOUR CODE HERE
