# %% [markdown]
# # Exercise: Simple Image Manipulation
#
# **Goal:** create a 100x100 grayscale image, then modify parts of it.
#
# Follow the steps below and write code in the empty cells.

# %% [markdown]
# ### Tasks
# 1. Create a 100x100 array of random integers 0-255 (dtype uint8).
# 2. Create a copy and set the bottom half to 0 (black).
# 3. Display original and modified images side-by-side.
# 4. Save the modified image to `/mnt/data/ml_projects/image_bottom_black.png`.

# %%
# 1) create image
# YOUR CODE HERE

# %%
# 2) modify bottom half
# YOUR CODE HERE

# %%
# 3) display side-by-side
# YOUR CODE HERE

# %%
# 4) save file
# YOUR CODE HERE
