# %% [markdown]
# # Exercise: Sales Dataset Analyzer
#
# Tasks:
# 1. Create the DataFrame shown.
# 2. Add `revenue = price * quantity`.
# 3. Find top-2 products by revenue.
# 4. Group revenue by category and plot a bar chart.
#
# Write code in the cells below.

# %%
# 1) create DataFrame
# YOUR CODE

# %%
# 2) add revenue
# YOUR CODE

# %%
# 3) top-2 products
# YOUR CODE

# %%
# 4) group and plot
# YOUR CODE
