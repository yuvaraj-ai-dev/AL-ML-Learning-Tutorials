# %% [markdown]
# # Exercise: ML Preparation
#
# Tasks:
# 1. Create x as linspace and y = 2*x + noise.
# 2. Introduce a missing value in x.
# 3. Drop or fill missing values.
# 4. Normalize x and y (without sklearn: use (x-mean)/std).
# 5. Plot normalized x vs y.

# %%
# YOUR CODE HERE
