# %% [markdown]
# # Exercise: Simple Finance Tracker
#
# Tasks:
# 1. Create the DataFrame with date,income,expense,category.
# 2. Add `net = income - expense`.
# 3. Compute total income & expenses.
# 4. Plot net over time and a pie chart of expenses by category.

# %%
# YOUR CODE HERE
