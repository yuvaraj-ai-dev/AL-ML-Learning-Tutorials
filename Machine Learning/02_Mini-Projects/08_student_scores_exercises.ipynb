# %% [markdown]
# # Exercise: Student Score Analyzer
#
# Tasks:
# 1. Create the DataFrame with students and scores.
# 2. Compute each student's average and add as column `avg`.
# 3. Compute average per subject.
# 4. Plot student averages sorted descending.

# %%
# YOUR CODE HERE
