# %% [markdown]
# # Motion Estimation and Tracking
#
# Optical flow, background subtraction, centroid tracking, Kalman filter intro.
#
# ### Example: Farneback dense optical flow visualization

# %%
import cv2
cap = cv2.VideoCapture('datasets/sample_videos/sample_clip.mp4')
ret,prev = cap.read()
prev_gray = cv2.cvtColor(prev, cv2.COLOR_BGR2GRAY)
ret,frame = cap.read()
frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
flow = cv2.calcOpticalFlowFarneback(prev_gray, frame_gray, None,0.5,3,15,3,5,1.2,0)
