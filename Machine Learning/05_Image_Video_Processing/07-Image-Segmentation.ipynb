# %% [markdown]
# # Image Segmentation
#
# Thresholding, morphological ops, watershed, grabcut, clustering.
#
# ### Example: Otsu threshold

# %%
import cv2
img = cv2.imread('datasets/sample_images/coins.png',0)
ret,th = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
