# %% [markdown]
# # Advanced Video Applications
#
# Action recognition overview, multi-object tracking ideas, video summarization, realtime tips.
#
# ### Example: combine detection + tracking (skeleton)

# %%
# detect frames -> track using simple centroid/IOU tracker -> save outputs
