# %% [markdown]
# # Setup and Introduction
#
# This notebook explains how to set up the environment and quick intro to libraries used throughout the course.
#
# ## Goals
# - Provide environment setup (venv/conda)
# - Quick example: read & display an image
#
# ### Requirements
# See `requirements.txt` in the project root.
#
# ### Quick demo

# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('datasets/sample_images/sample1.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis('off')
