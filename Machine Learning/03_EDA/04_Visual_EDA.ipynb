# %% [markdown]
# # 04 — Visual EDA
# Matplotlib & Seaborn basics.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('titanic')
sns.boxplot(x='pclass', y='fare', data=df); plt.show()

# %% [markdown]
# ### Exercises
# 1. Create violin plot for age by class.
