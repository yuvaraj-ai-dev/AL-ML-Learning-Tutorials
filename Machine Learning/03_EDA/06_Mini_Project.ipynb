# %% [markdown]
# # 06 — Mini Project
# Full EDA workflow.

# %%
import seaborn as sns
import pandas as pd
df = sns.load_dataset('titanic')
df.head()

# %% [markdown]
# ### Project Tasks
# - Clean data
# - Visualize relationships
# - Build small baseline model
