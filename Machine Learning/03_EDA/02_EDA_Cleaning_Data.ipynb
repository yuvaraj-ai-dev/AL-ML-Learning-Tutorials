# %% [markdown]
# # 02 — Data Cleaning
# Handling missing values, types, duplicates.

# %%
import seaborn as sns
import pandas as pd
df = sns.load_dataset('titanic')
df.isna().sum()

# %% [markdown]
# ### Exercises
# 1. Impute median age.
# 2. Convert pclass to category.
