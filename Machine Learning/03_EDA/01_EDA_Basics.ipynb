# %% [markdown]
# # 01 — EDA Basics
# Learn what EDA is and how to inspect a dataset.

# %% [markdown]
# ## What is EDA?
# EDA helps you understand data patterns before modeling.

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')
df.head()

# %% [markdown]
# ### Exercises
# 1. Load any seaborn dataset.
# 2. Print `.info()` and `.describe()`.
